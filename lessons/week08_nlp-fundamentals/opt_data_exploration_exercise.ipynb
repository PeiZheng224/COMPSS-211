# %% [markdown]
# ## Additional Exercise: Exploring & Cleaning the NYC 311 Service Requests Dataset
#
# Dataset: NYC 311 Service Requests
#
# This is a large dataset of city service complaints (with location, date, category, and description text). It offers a mix of structured data (categories, dates) and unstructured text (“descriptor” field).
#
# Your goal: Identify the most frequent issues in Brooklyn vs. Manhattan in 2023 and visualize the trend of noise complaints over time.
#
# This will involve data wrangling, grouping, and plotting.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("new-york-city/ny-311-service-requests")

print("Path to dataset files:", path)
# Out:
# Resuming download from 844103680 bytes (2631861400 bytes left)...
# Resuming download from https://www.kaggle.com/api/v1/datasets/download/new-york-city/ny-311-service-requests?dataset_version_number=53 (844103680/3475965080) bytes left.
# 100%|██████████| 3.24G/3.24G [01:03<00:00, 41.3MB/s]
# Extracting files...
# Path to dataset files: /Users/tomvannuenen/.cache/kagglehub/datasets/new-york-city/ny-311-service-requests/versions/53

# %% [markdown]
# Import your packages

# %% [markdown]
# Step 1 – Initial Inspection
#
# Look for:
# - Which columns have many NaN values?
# - Are date/time fields properly recognized?
# - What categorical columns (e.g. Complaint Type, Borough) look messy?

# %% [markdown]
# Step 2 – Handling Missing and Incomplete Data
#
# - Convert created_date to datetime and drop rows without it
# - Fill missing boroughs as "UNKNOWN"
# - Standardize column names

# %% [markdown]
# Step 3 – Aggregate & Explore
#
# Look for:
# - Top complaint types
# - Complaints per borough
# - Trend over time (monthly)

# %% [markdown]
# Step 4 – Mini Challenge
#
# Try one or more of the following:
# - Which borough has the highest number of noise complaints per capita (using a borough population lookup)?
# - Plot the top 5 complaint types over the past year.
# - Identify common words in descriptor_clean for a specific complaint type (e.g., “Noise – Residential”).
